# %%
import imdb
import pandas as pd

# %%
ia = imdb.IMDb()

# %%
community_search = ia.search_movie('community')
community_search
# Out:
# [<Movie id:1439629[http] title:_"Community" (2009)_>,
#  <Movie id:2087720[http] title:_Community (2012)_>,
#  <Movie id:0154206[http] title:_Bara-Dari (1955)_>,
#  <Movie id:0059431[http] title:_Marriage on the Rocks (1965)_>,
#  <Movie id:3483758[http] title:_Community: Miracle on Jeff's Street (2013) (TV)_>,
#  <Movie id:2148236[http] title:_Community: Abed's Master Key (2012) (TV)_>,
#  <Movie id:4070670[http] title:_Community Swingers (2006) (V)_>,
#  <Movie id:3152638[http] title:_Community: Study Break (2010)_>,
#  <Movie id:5531006[http] title:_Community (None)_>,
#  <Movie id:0097100[http] title:_Communion (1989)_>,
#  <Movie id:8355268[http] title:_"The Community" (2017)_>,
#  <Movie id:5867978[http] title:_"Community" (2014)_>,
#  <Movie id:9094000[http] title:_Community (2015)_>,
#  <Movie id:7130540[http] title:_Community (2016)_>,
#  <Movie id:1070934[http] title:_"Craft in America" Community (2007)_>,
#  <Movie id:1117021[http] title:_"Fear Itself" Community (2008)_>,
#  <Movie id:4344638[http] title:_"Zero: Black Blood" Community (2014)_>,
#  <Movie id:6432476[http] title:_"Android Employed" Community (2017)_>,
#  <Movie id:4563396[http] title:_"Hope in Motion" Community (2012)_>,
#  <Movie id:1943676[http] title:_Community (1947)_>]

# %%
rickAndMorty_search = ia.search_movie('rick and morty')
rickAndMorty_search
# Out:
# [<Movie id:2861424[http] title:_"Rick and Morty" (2013)_>,
#  <Movie id:7408236[http] title:_"The Philosophy of" Rick and Morty (2015)_>,
#  <Movie id:7068176[http] title:_"Drinking Games with Dan and Veronica" Rick and Morty (2016)_>,
#  <Movie id:6852592[http] title:_Rick and Morty Ruin a Fan Film (2017)_>,
#  <Movie id:7119072[http] title:_Rick and Morty Strike Again! (2017)_>,
#  <Movie id:5950978[http] title:_Rick and Morty: State of Georgia Vs. Denver Fenton Allen (2016)_>,
#  <Movie id:7149328[http] title:_Rick and Morty Exquisite Corpse (2017) (V)_>,
#  <Movie id:3343614[http] title:_Rick and Morty: Comic-Con Panel 2013 (2013)_>,
#  <Movie id:9049822[http] title:_"Screen Rant Pitch Meetings" Rick and Morty (2018)_>,
#  <Movie id:8535214[http] title:_"San Diego Comic-Con 2016" Rick and Morty (2016)_>,
#  <Movie id:7689546[http] title:_"Ricking Morty" (2017)_>,
#  <Movie id:5533172[http] title:_"The Toonsmyth Clog" Rick and Morty! PPG 2016! (2014)_>,
#  <Movie id:7003492[http] title:_"Gaming" Rick and Morty VR - Part 2 (2017)_>,
#  <Movie id:5195738[http] title:_The Misadventures of Rick and Morty (2015)_>,
#  <Movie id:1184866[http] title:_"Abroad in Britain" Brick and Mortars (1990)_>,
#  <Movie id:7414498[http] title:_"ScreenPrism" Rick and Morty: Why is Rick Such a Rick? (2017)_>,
#  <Movie id:7458930[http] title:_Rick and Morty: Alien Covenant (2017) (V)_>,
#  <Movie id:7003902[http] title:_"Gaming" Rick and Morty VR - Finale (2017)_>,
#  <Movie id:8657272[http] title:_"Color Circuit: Ludum Tempus" Rick and Morty Munchkin (2018)_>,
#  <Movie id:7851384[http] title:_"The Damien & Shayne Show" Rick and Morty Play GTA V! (2017)_>]

# %%
community_ep = ia.get_movie_episodes('1439629')
rickandmorty_ep = ia.get_movie_episodes('2861424')

# %%
#can I create a list of these items? 
master_list = [community_ep,rickandmorty_ep] # yes you can

# %%
#created lots of loops to scale the process
master_df = pd.DataFrame()

for x in range(len(master_list)):
    for y in master_list[x]['data']['episodes'].keys():
        for z in master_list[x]['data']['episodes'][y].keys():
            temp_dict = master_list[x]['data']['episodes'][y][z].data
            temp_df = pd.DataFrame(temp_dict, index = [0])
            temp_df['episode of'] = temp_df['episode of'].astype(str)
            master_df = master_df.append(temp_df)
            #print(f"Order {x} Season{y} episode{z}")
# Out:
# C:\Users\jbonanno\Anaconda3\lib\site-packages\pandas\core\frame.py:7116: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151 entries, 0 to 0
# Data columns (total 10 columns):
# episode              151 non-null int64
# episode of           151 non-null object
# kind                 151 non-null object
# original air date    142 non-null object
# plot                 151 non-null object
# rating               141 non-null float64
# season               151 non-null int64
# title                151 non-null object
# votes                141 non-null float64
# year                 142 non-null object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 13.0+ KB

# %%
#reset index for pandas
master_df = master_df.reset_index(drop=True)

# %%
#confirm any unique values in kind column
#print(master_df['kind'].unique())
#drop kind column
master_df = master_df.drop('kind',axis = 1)

# %%
#I don't consider either unaired pilot cannon, so I'm dropping them
master_df[master_df['episode']==0]
# Out:
# Empty DataFrame
# Columns: [episode, episode of, original air date, plot, rating, season, title, votes, year]
# Index: []

# %%
#clean up (TV Series from Episode of)

#remove everything to the right of the ( by subsetting the first part of the string
master_df['episode of'] = master_df['episode of'].str.split("(").str[0]

#removes the trailing white space. Can't see it, but I know it is there
master_df['episode of'] = master_df['episode of'].str.strip()

# %%
#sort by the orginal air date

#month has a period at the end of it, so need to remove it
master_df['original air date'] = master_df['original air date'].str.replace('.','')

# %%
master_df.tail()
# Out:
#      episode      episode of original air date  \
# 146        6  Rick and Morty               NaN
# 147        7  Rick and Morty               NaN
# 148        8  Rick and Morty               NaN
# 149        9  Rick and Morty               NaN
# 150       10  Rick and Morty               NaN
#
#                                                   plot  rating  season  \
# 146  \n  Know what this is about?\n Be the first on...     NaN       4
# 147  \n  Know what this is about?\n Be the first on...     NaN       4
# 148  \n  Know what this is about?\n Be the first on...     NaN       4
# 149  \n  Know what this is about?\n Be the first on...     NaN       4
# 150  \n  Know what this is about?\n Be the first on...     NaN       4
#
#              title  votes year
# 146   Episode #4.6    NaN  NaN
# 147   Episode #4.7    NaN  NaN
# 148   Episode #4.8    NaN  NaN
# 149   Episode #4.9    NaN  NaN
# 150  Episode #4.10    NaN  NaN

# %%
#convert to date time. 
#using pd.to_datetime, pandas will automatiically figure it out
master_df['original air date'] = pd.to_datetime(master_df['original air date'])

# %%
#sort from oldest to newest
master_df = master_df.sort_values(by = ['original air date','season','episode'])

# %%
master_df = master_df.reset_index(drop=True)

# %%
master_df
# Out:
#      episode      episode of original air date  \
# 0          1       Community        2009-09-17
# 1          2       Community        2009-09-24
# 2          3       Community        2009-10-01
# 3          4       Community        2009-10-08
# 4          5       Community        2009-10-15
# ..       ...             ...               ...
# 146        6  Rick and Morty               NaT
# 147        7  Rick and Morty               NaT
# 148        8  Rick and Morty               NaT
# 149        9  Rick and Morty               NaT
# 150       10  Rick and Morty               NaT
#
#                                                   plot    rating  season  \
# 0    \n    An ex-lawyer is forced to return to comm...  7.801235       1
# 1    \n    Jeff takes steps to ensure that Brita wi...  7.901235       1
# 2    \n    Brita comes between Abed and his father ...  8.301235       1
# 3    \n    Jeff and Shirley bond by making fun of B...  8.201235       1
# 4    \n    Señor Chang is on the hunt for a cheater...  7.901235       1
# ..                                                 ...       ...     ...
# 146  \n  Know what this is about?\n Be the first on...       NaN       4
# 147  \n  Know what this is about?\n Be the first on...       NaN       4
# 148  \n  Know what this is about?\n Be the first on...       NaN       4
# 149  \n  Know what this is about?\n Be the first on...       NaN       4
# 150  \n  Know what this is about?\n Be the first on...       NaN       4
#
#                      title   votes  year
# 0                    Pilot  2585.0  2009
# 1              Spanish 101  2245.0  2009
# 2     Introduction to Film  2182.0  2009
# 3        Social Psychology  1993.0  2009
# 4    Advanced Criminal Law  1914.0  2009
# ..                     ...     ...   ...
# 146           Episode #4.6     NaN   NaN
# 147           Episode #4.7     NaN   NaN
# 148           Episode #4.8     NaN   NaN
# 149           Episode #4.9     NaN   NaN
# 150          Episode #4.10     NaN   NaN
#
# [151 rows x 9 columns]

# %%
master_df.to_csv("community_rick_morty.csv")
