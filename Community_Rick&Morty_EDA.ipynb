# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt # to change styles
import matplotlib.style as style

#import magic line to show graphs in jupyter notebook
# %matplotlib inline

#need to clean episode 0 that is showing up...

# %%
#formating for seaborn
#style.available

# %%
style.use('seaborn')

# %%
df = pd.read_csv('community_rick_morty.csv',index_col = 0)

# %%
df.head()
# Out:
#    episode episode of original air date  \
# 0        1  Community        2009-09-17
# 1        2  Community        2009-09-24
# 2        3  Community        2009-10-01
# 3        4  Community        2009-10-08
# 4        5  Community        2009-10-15
#
#                                                 plot    rating  season  \
# 0  \n    An ex-lawyer is forced to return to comm...  7.801235       1
# 1  \n    Jeff takes steps to ensure that Brita wi...  7.901235       1
# 2  \n    Brita comes between Abed and his father ...  8.301235       1
# 3  \n    Jeff and Shirley bond by making fun of B...  8.201235       1
# 4  \n    Señor Chang is on the hunt for a cheater...  7.901235       1
#
#                    title   votes    year
# 0                  Pilot  2585.0  2009.0
# 1            Spanish 101  2245.0  2009.0
# 2   Introduction to Film  2182.0  2009.0
# 3      Social Psychology  1993.0  2009.0
# 4  Advanced Criminal Law  1914.0  2009.0

# %%
df[(df['episode of']== 'Rick and Morty')&(df['season']==4)]
# Out:
#      episode      episode of original air date  \
# 141        1  Rick and Morty        2019-11-01
# 142        2  Rick and Morty               NaN
# 143        3  Rick and Morty               NaN
# 144        4  Rick and Morty               NaN
# 145        5  Rick and Morty               NaN
# 146        6  Rick and Morty               NaN
# 147        7  Rick and Morty               NaN
# 148        8  Rick and Morty               NaN
# 149        9  Rick and Morty               NaN
# 150       10  Rick and Morty               NaN
#
#                                                   plot  rating  season  \
# 141             \n    Plot is unknown at this time         NaN       4
# 142  \n  Know what this is about?\n Be the first on...     NaN       4
# 143  \n  Know what this is about?\n Be the first on...     NaN       4
# 144  \n  Know what this is about?\n Be the first on...     NaN       4
# 145  \n  Know what this is about?\n Be the first on...     NaN       4
# 146  \n  Know what this is about?\n Be the first on...     NaN       4
# 147  \n  Know what this is about?\n Be the first on...     NaN       4
# 148  \n  Know what this is about?\n Be the first on...     NaN       4
# 149  \n  Know what this is about?\n Be the first on...     NaN       4
# 150  \n  Know what this is about?\n Be the first on...     NaN       4
#
#              title  votes    year
# 141   Episode #4.1    NaN  2019.0
# 142   Episode #4.2    NaN     NaN
# 143   Episode #4.3    NaN     NaN
# 144   Episode #4.4    NaN     NaN
# 145   Episode #4.5    NaN     NaN
# 146   Episode #4.6    NaN     NaN
# 147   Episode #4.7    NaN     NaN
# 148   Episode #4.8    NaN     NaN
# 149   Episode #4.9    NaN     NaN
# 150  Episode #4.10    NaN     NaN

# %%
df.drop(df.index[141:151])
# Out:
#      episode      episode of original air date  \
# 0          1       Community        2009-09-17
# 1          2       Community        2009-09-24
# 2          3       Community        2009-10-01
# 3          4       Community        2009-10-08
# 4          5       Community        2009-10-15
# ..       ...             ...               ...
# 136        6  Rick and Morty        2017-08-27
# 137        7  Rick and Morty        2017-09-10
# 138        8  Rick and Morty        2017-09-17
# 139        9  Rick and Morty        2017-09-24
# 140       10  Rick and Morty        2017-10-01
#
#                                                   plot    rating  season  \
# 0    \n    An ex-lawyer is forced to return to comm...  7.801235       1
# 1    \n    Jeff takes steps to ensure that Brita wi...  7.901235       1
# 2    \n    Brita comes between Abed and his father ...  8.301235       1
# 3    \n    Jeff and Shirley bond by making fun of B...  8.201235       1
# 4    \n    Señor Chang is on the hunt for a cheater...  7.901235       1
# ..                                                 ...       ...     ...
# 136  \n    Following a stressful adventure, Rick an...  9.001235       3
# 137  \n    Whilst Rick and Morty go off to adventur...  9.801235       3
# 138  \n    Rick reveals to Morty his "Morty's mind ...  8.901235       3
# 139  \n    Rick brings Beth to a world he created f...  8.001235       3
# 140  \n    Rick and Morty are called upon by the pr...  8.201235       3
#
#                          title    votes    year
# 0                        Pilot   2585.0  2009.0
# 1                  Spanish 101   2245.0  2009.0
# 2         Introduction to Film   2182.0  2009.0
# 3            Social Psychology   1993.0  2009.0
# 4        Advanced Criminal Law   1914.0  2009.0
# ..                         ...      ...     ...
# 136      Rest and Ricklaxation   7238.0  2017.0
# 137       The Ricklantis Mixup  20663.0  2017.0
# 138       Morty's Mind Blowers   6656.0  2017.0
# 139          The ABC's of Beth   5508.0  2017.0
# 140  The Rickchurian Mortydate   5528.0  2017.0
#
# [141 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151 entries, 0 to 150
# Data columns (total 9 columns):
# episode              151 non-null int64
# episode of           151 non-null object
# original air date    142 non-null object
# plot                 151 non-null object
# rating               141 non-null float64
# season               151 non-null int64
# title                151 non-null object
# votes                141 non-null float64
# year                 142 non-null float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 16.8+ KB

# %%
# Average Rating by TV Show
df.groupby('episode of')['rating'].mean().sort_values(ascending = False)

#wow, people like Ange better than Buffy...
# Out:
# episode of
# Rick and Morty    8.739944
# Community         8.365780
# Name: rating, dtype: float64

# %%
#describe returns a df so can index only the columns desired
df.groupby('episode of')['rating'].describe()[['count','mean','std','min','max']].sort_values(by = 'mean',ascending = False)
# Out:
#                 count      mean       std       min       max
# episode of
# Rick and Morty   31.0  8.739944  0.530834  7.701235  9.801235
# Community       110.0  8.365780  0.638459  6.801235  9.801235

# %%
# Average Rating by TV Show
df.groupby('episode of')['rating'].mean().sort_values(ascending = False).plot(kind = 'bar')

# %%
#simple stats tutorial 
#https://machinelearningmastery.com/parametric-statistical-significance-tests-in-python/

# %%
#is atla significantly better than lok?
#what about tdp?

#Null: Ratings betwween atla & lok is the same
#Alternative: Ratings betwween atla & lok are different
#alpha = .05
from scipy.stats import ttest_ind

# %%
# returns 2 values, the calculated t-stat and the two wailed p-value
stat, p = ttest_ind(df['rating'][df['episode of']=='Rick and Morty'], #data 1
                    df['rating'][df['episode of']=='Community']) #data 2
# Out:
# C:\Users\jbonanno\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\jbonanno\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\jbonanno\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
#atla vs lok
alpha = .05
if p>alpha:
    print(f'The T value was:{stat}. The P value was:{p} Fail to reject null')
else:
    print(f'The T value was:{stat}. P value was:{p} Reject null hypothesis')
    
#still can't tell if they are different
# Out:
# The T value was:nan. P value was:nan Reject null hypothesis

# %%
#how does histogram look by show?
plt.figure(figsize = (16,6))
df.groupby('episode of')['rating'].plot(kind = 'hist', alpha = .4, legend = True)
# Out:
# episode of
# Community         AxesSubplot(0.125,0.125;0.775x0.755)
# Rick and Morty    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: rating, dtype: object

# %%
#what are the worst episodes?
df[df['rating']<7.0].sort_values(by = 'rating')
# Out:
#     episode episode of original air date  \
# 77        7  Community        2013-03-21
#
#                                                  plot    rating  season  \
# 77  \n    Dean Pelton and Annie try to land a "wha...  6.801235       4
#
#                           title   votes    year
# 77  Economics of Marine Biology  1451.0  2013.0

# %%
#how about the best?
df[df['rating']>9.5].sort_values(by = 'rating',ascending = False)

#top 3 rated Buffy episodes are the most unique

#the musical episode
#the opposite of the music episode
#the one where they remove music
# Out:
#      episode      episode of original air date  \
# 22        23       Community        2010-05-06
# 52         4       Community        2011-10-13
# 137        7  Rick and Morty        2017-09-10
# 47        23       Community        2011-05-05
# 48        24       Community        2011-05-12
# 120       13       Community        2015-06-02
# 124        4  Rick and Morty        2015-08-16
# 131        1  Rick and Morty        2017-04-01
# 38        14       Community        2011-02-03
# 68        20       Community        2012-05-17
#
#                                                   plot    rating  season  \
# 22   \n    Greendale Community College is transform...  9.801235       1
# 52   \n    At Abed and Troy's housewarming party, J...  9.801235       3
# 137  \n    Whilst Rick and Morty go off to adventur...  9.801235       3
# 47   \n    In a "spaghetti western" parody, Pierce ...  9.701235       2
# 48   \n    When the study group learns that there's...  9.601235       2
# 120  \n    As their sixth year at Greendale draws t...  9.601235       6
# 124  \n    The Smith house is locked down after par...  9.601235       2
# 131  \n    Rick, still in galactic prison, puts an ...  9.601235       3
# 38   \n    The study group plays Dungeons & Dragons...  9.501235       2
# 68   \n    The Study Group must help Hawthorne win ...  9.501235       3
#
#                                               title    votes    year
# 22                                   Modern Warfare   6971.0  2010.0
# 52                            Remedial Chaos Theory   5663.0  2011.0
# 137                            The Ricklantis Mixup  20663.0  2017.0
# 47                          A Fistful of Paintballs   3934.0  2011.0
# 48                        For a Few Paintballs More   3172.0  2011.0
# 120  Emotional Consequences of Broadcast Television   3014.0  2015.0
# 124                                   Total Rickall  10804.0  2015.0
# 131                      The Rickshank Rickdemption  14027.0  2017.0
# 38                      Advanced Dungeons & Dragons   3376.0  2011.0
# 68                          Digital Estate Planning   2990.0  2012.0

# %%
df.iloc[137]['plot']
# Out:
# '\n    Whilst Rick and Morty go off to adventure in Atlantis, we take a look at how the Citadel has rebuilt itself since both Rick and Morty visited.    '

# %%
plt.figure(figsize = (16,6))
sns.boxplot(x ='episode of',y='rating',data = df)

#Buffy's low is way lower than Angel's

# %%
df2 = df[['episode of','season','episode','rating']].pivot_table(index = ['episode of','season','episode']).copy()

# %%
# I did it! Wonder how it woudl look relative to creating a new column with s1-ep1 
# need to make this a bigger and wider... 
#plt.figure(figsize = (16,6))
df2.loc['Rick and Morty'].plot(figsize = (16,6), title = 'Rick & Morty')
df2.loc['Community'].plot(figsize = (16,6), title = 'Community')

#Show observations 

#honestly, this is too much data to digest -- hard to draw meaningful conclusions from this

# %%
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(16,8), sharey = True)

sns.boxplot(x ='season',y='rating',data = df[df['episode of']== 'Rick and Morty'],ax=ax1)
sns.boxplot(x ='season',y='rating',data = df[df['episode of']== 'Community'],ax=ax2)

#interesting stuff

#for rick and morty, widest variaton by far in Season 3. It also had people's favorite episode in the Ricklantis Mixup

#people did no like community after season 3, which the average is a lot lower.
